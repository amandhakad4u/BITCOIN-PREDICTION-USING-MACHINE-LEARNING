# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
import arch
register_matplotlib_converters()
# %matplotlib inline
import warnings
import requests
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('BTSdategropby.csv', encoding = "ISO-8859-1")

# %%
print(df.shape)
# strip column names
df=df.rename(columns=lambda x: x.strip())
cols=df.columns


print('ColumnName, DataType, MissingValues')
for i in cols:
    print(i, ',', df[i].dtype,',',df[i].isnull().any())
# Out:
# (365, 7)
# ColumnName, DataType, MissingValues
# Date , object , False
# Low , float64 , False
# High , float64 , False
# Open , float64 , False
# Close , float64 , False
# Volume , float64 , False
# Mean , float64 , True

# %%
# feature creation for better representation of price on a day
df['Mean'] = (df['Low'] + df['High'])/2

# remove NaNs and Nones
df = df.dropna()

# data preview
print(df.head())


# making copy for making changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']


# normalizing exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X= scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print(X.head())

# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print(y.head())


# train-test split
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()


from statsmodels.tsa.statespace.sarimax import SARIMAX

# Init the model
predic_garch =[]
for i in range(test_size):
  model= SARIMAX(pd.concat([train_y,test_y.iloc[:i+1]]),
  exog=pd.concat([train_X,test_X.iloc[:i+1]]),
  order=(0,1,1),
  seasonal_order =(0, 0, 1, 12),
  enforce_invertibility=False, enforce_stationarity=False)
  results= model.fit()
  garch = arch.arch_model(results.resid, p=1, q=1,vol='GARCH')
  garch_model = garch.fit(update_freq=1)
  garch_forecast = garch_model.forecast(start = train_size-1,horizon=1,method='simulation')
  predicted_et = garch_forecast.mean['h.1'].iloc[-1]
  predic_garch.append(predicted_et)
  print(predicted_et)


model= SARIMAX(train_y,
 exog=train_X,
 order=(0,1,1),
 seasonal_order =(0, 0, 1, 12),
 enforce_invertibility=False, enforce_stationarity=False)


# training the model
results= model.fit()

# plotting residuals
results.resid.plot()


# making preditions
predictions= results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)
act= pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={'predicted_mean':'Pred'}, inplace=True)
print(predictions)
for i in range(len(predictions)) :
  predictions.iloc[i,0]= predictions.iloc[i,0]+predic_garch[i]



# plotting the results
trainPredict = sc_out.inverse_transform(predictions[['Pred']])
testPredict = sc_out.inverse_transform(predictions[['Actual']])

plt.figure(figsize=(20,10))
plt.plot(predictions.index, trainPredict, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

from statsmodels.tools.eval_measures import rmse
error=rmse(trainPredict, testPredict)
print("RMSE:",error)
# Out:
#                Date       Low      High      Open     Close    Volume  \
# 0  31-12-2017 00:00  12596.12  12640.00  12640.00  12596.13  0.496065
# 1  30-12-2017 00:00  14300.00  14351.00  14351.00  14300.01  8.208843
# 2  29-12-2017 00:00  14434.00  14497.00  14436.99  14497.00  7.485913
# 3  28-12-2017 00:00  15357.11  15404.99  15390.05  15399.99  1.503470
# 4  27-12-2017 00:00  15685.70  15764.45  15764.45  15685.70  6.749718
#
#         Mean
# 0  12618.060
# 1  14325.500
# 2  14465.500
# 3  15381.050
# 4  15725.075
#                  Low      High      Open     Close    Volume      Mean
# Date
# 2017-12-30  0.735586  0.737260  0.737261  0.735586  0.038875  0.736424
# 2017-12-29  0.742875  0.745191  0.741932  0.746302  0.035451  0.744034
# 2017-12-28  0.793090  0.794514  0.793703  0.795422  0.007120  0.793802
# 2017-12-27  0.810964  0.814040  0.814041  0.810964  0.031965  0.812503
# 2017-12-26  0.715135  0.714147  0.714148  0.715135  0.000531  0.714641
#             BTC Price next day
# Date
# 2017-12-30            0.643609
# 2017-12-29            0.736424
# 2017-12-28            0.744034
# 2017-12-27            0.793802
# 2017-12-26            0.812503
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.54713D+00    |proj g|=  6.30993D+00
#
# At iterate    5    f= -2.55259D+00    |proj g|=  3.56868D-01
#
# At iterate   10    f= -2.55504D+00    |proj g|=  6.92460D-01
#
# At iterate   15    f= -2.55520D+00    |proj g|=  5.38625D-01
#
# At iterate   20    f= -2.56026D+00    |proj g|=  3.61461D-01
#
# At iterate   25    f= -2.56164D+00    |proj g|=  5.68883D-02
#
# At iterate   30    f= -2.56202D+00    |proj g|=  1.56246D+00
#
# At iterate   35    f= -2.56577D+00    |proj g|=  1.53127D+00
#
# At iterate   40    f= -2.56605D+00    |proj g|=  5.24574D-02
#
# At iterate   45    f= -2.56606D+00    |proj g|=  1.96424D-02
#
# At iterate   50    f= -2.56607D+00    |proj g|=  1.41884D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     62      1     0     0   1.419D-02  -2.566D+00
#   F =  -2.5660661534707869
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4.887143953996837e+19
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 4.2640815972827936e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 92.79830995849173
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 1462.108482028496
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -105.92347878390301
# Iteration:      6,   Func. Count:     53,   Neg. LLF: -605.2174319756257
# Iteration:      7,   Func. Count:     58,   Neg. LLF: 37096.87207796396
# Iteration:      8,   Func. Count:     66,   Neg. LLF: 167399355.10526276
# Iteration:      9,   Func. Count:     80,   Neg. LLF: -703.7907819357004
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -703.790784618292
#             Iterations: 13
#             Function evaluations: 80
#             Gradient evaluations: 9
# -0.0012858200033066302
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.54900D+00    |proj g|=  6.32533D+00
#
# At iterate    5    f= -2.55443D+00    |proj g|=  3.81930D-01
#
# At iterate   10    f= -2.55681D+00    |proj g|=  1.31329D+00
#
# At iterate   15    f= -2.55703D+00    |proj g|=  3.62344D-01
#  This problem is unconstrained.
# At iterate   20    f= -2.56116D+00    |proj g|=  1.72440D+00
#
# At iterate   25    f= -2.56359D+00    |proj g|=  3.18194D-02
#
# At iterate   30    f= -2.56646D+00    |proj g|=  2.01513D+00
#
# At iterate   35    f= -2.56793D+00    |proj g|=  1.02620D-02
#
# At iterate   40    f= -2.56794D+00    |proj g|=  1.80381D-02
#
# At iterate   45    f= -2.56943D+00    |proj g|=  2.20912D+00
#
# At iterate   50    f= -2.57985D+00    |proj g|=  4.17969D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     63      1     0     0   4.180D-01  -2.580D+00
#   F =  -2.5798477564577076
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 4.350469446182613e+19
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 8528659158.141605
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 17.584729537063282
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 27.257814571873723
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -11.06489581961671
# Iteration:      6,   Func. Count:     54,   Neg. LLF: -334.89412382113187
# Iteration:      7,   Func. Count:     60,   Neg. LLF: 2.6043895348192824e+18
# Iteration:      8,   Func. Count:     73,   Neg. LLF: -746.6748373574092
# Iteration:      9,   Func. Count:     78,   Neg. LLF: 52751.81943825954
# Iteration:     10,   Func. Count:     91,   Neg. LLF: 85091074.42009217
# Iteration:     11,   Func. Count:    103,   Neg. LLF: 4.788768294665826e+17
# Iteration:     12,   Func. Count:    114,   Neg. LLF: -750.5023104941522
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -750.5023122428353
#             Iterations: 16
#             Function evaluations: 114
#             Gradient evaluations: 12
# -0.0007943178232791453
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.55087D+00    |proj g|=  6.34114D+00
#
# At iterate    5    f= -2.55628D+00    |proj g|=  4.15584D-01
#
# At iterate   10    f= -2.55833D+00    |proj g|=  2.09350D+00
#  This problem is unconstrained.
# At iterate   15    f= -2.55892D+00    |proj g|=  2.92150D-01
#
# At iterate   20    f= -2.56311D+00    |proj g|=  9.00748D-02
#
# At iterate   25    f= -2.56542D+00    |proj g|=  3.13330D-02
#
# At iterate   30    f= -2.56696D+00    |proj g|=  9.10755D-01
#
# At iterate   35    f= -2.56981D+00    |proj g|=  4.49051D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     38     65      1     0     0   4.675D-03  -2.570D+00
#   F =  -2.5698148994041987
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 244575352.50400004
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 3.900364000518839e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 81.02011327638685
# Iteration:      4,   Func. Count:     41,   Neg. LLF: -1.7197943956794184
# Iteration:      5,   Func. Count:     46,   Neg. LLF: -74.58763161912391
# Iteration:      6,   Func. Count:     51,   Neg. LLF: 171.4027187301117
# Iteration:      7,   Func. Count:     58,   Neg. LLF: 2831.93281098382
# Iteration:      8,   Func. Count:     64,   Neg. LLF: -297.7838041804956
# Iteration:      9,   Func. Count:     69,   Neg. LLF: -645.2012481194581
# Iteration:     10,   Func. Count:     74,   Neg. LLF: 1839254301.2472193
# Iteration:     11,   Func. Count:     89,   Neg. LLF: 4330555685076.8003
# Iteration:     12,   Func. Count:    104,   Neg. LLF: 511409961.67402935
# Iteration:     13,   Func. Count:    119,   Neg. LLF: -204.28496597671716
# Iteration:     14,   Func. Count:    127,   Neg. LLF: 90073.2465216082
# Iteration:     15,   Func. Count:    133,   Neg. LLF: 717708479.5117481
# Iteration:     16,   Func. Count:    148,   Neg. LLF: 1375504.7224464198
# Iteration:     17,   Func. Count:    159,   Neg. LLF: 47756.47739585781
# Iteration:     18,   Func. Count:    165,   Neg. LLF: 24295594156.05846
# Iteration:     19,   Func. Count:    177,   Neg. LLF: -711.167660513433
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -711.1676629205272
#             Iterations: 23
#             Function evaluations: 177
#             Gradient evaluations: 19
# -0.0013008155553101172
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.55274D+00    |proj g|=  6.35659D+00
#
# At iterate    5    f= -2.55812D+00    |proj g|=  4.71017D-01
#
# At iterate   10    f= -2.55966D+00    |proj g|=  2.53461D+00
#
# At iterate   15    f= -2.56073D+00    |proj g|=  8.65298D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iterate   20    f= -2.56430D+00    |proj g|=  1.63955D+00
#
# At iterate   25    f= -2.56743D+00    |proj g|=  1.38405D-01
#
# At iterate   30    f= -2.57167D+00    |proj g|=  4.62507D-02
#
# At iterate   35    f= -2.57169D+00    |proj g|=  3.98413D-02
#
# At iterate   40    f= -2.57258D+00    |proj g|=  4.23336D-01
#
# At iterate   45    f= -2.58127D+00    |proj g|=  2.98455D+00
#
# At iterate   50    f= -2.58339D+00    |proj g|=  1.02833D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     68      1     0     0   1.028D+00  -2.583D+00
#   F =  -2.5833906438577925
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 210973508.24401483
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 2.0971471683794148e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -40.241315026578576
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 196.26289006271745
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -242.00047753884232
# Iteration:      6,   Func. Count:     53,   Neg. LLF: 3.336284518546054e+18
# Iteration:      7,   Func. Count:     66,   Neg. LLF: 202626.37023870362
# Iteration:      8,   Func. Count:     76,   Neg. LLF: -627.7617176783899
# Iteration:      9,   Func. Count:     81,   Neg. LLF: 293276756409.20215
# Iteration:     10,   Func. Count:     88,   Neg. LLF: 2887614.6717704893
# Iteration:     11,   Func. Count:     99,   Neg. LLF: 93187.87683291611
# Iteration:     12,   Func. Count:    104,   Neg. LLF: -644.6869050415755
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -644.6869070618993
#             Iterations: 16
#             Function evaluations: 104
#             Gradient evaluations: 12
# 0.00033704777627993805
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.55459D+00    |proj g|=  6.37186D+00
#
# At iterate    5    f= -2.55996D+00    |proj g|=  5.30278D-01
#
# At iterate   10    f= -2.56105D+00    |proj g|=  2.51155D+00
#  This problem is unconstrained.
# At iterate   15    f= -2.56352D+00    |proj g|=  1.66151D+00
#
# At iterate   20    f= -2.56874D+00    |proj g|=  7.39349D-01
#
# At iterate   25    f= -2.56931D+00    |proj g|=  3.34899D-01
#
# At iterate   30    f= -2.57354D+00    |proj g|=  1.10147D-01
#
# At iterate   35    f= -2.57355D+00    |proj g|=  2.57680D-02
#
# At iterate   40    f= -2.57568D+00    |proj g|=  3.00310D+00
#
# At iterate   45    f= -2.58514D+00    |proj g|=  3.19170D-02
#
# At iterate   50    f= -2.58559D+00    |proj g|=  3.08482D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     62      1     0     0   3.085D-02  -2.586D+00
#   F =  -2.5855900597407149
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 322003654.39124775
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 14461458036.652391
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -26.858796955580715
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 146.83646604169928
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -326.21619755428645
# Iteration:      6,   Func. Count:     53,   Neg. LLF: 588.4846435650143
# Iteration:      7,   Func. Count:     61,   Neg. LLF: -209.44817537042078
# Iteration:      8,   Func. Count:     67,   Neg. LLF: 216.41841796256688
# Iteration:      9,   Func. Count:     73,   Neg. LLF: 565.5437595419778
# Iteration:     10,   Func. Count:     81,   Neg. LLF: 2396888358.2628403
# Iteration:     11,   Func. Count:     92,   Neg. LLF: 21784.902769017626
# Iteration:     12,   Func. Count:    103,   Neg. LLF: -547.3946570362723
# Iteration:     13,   Func. Count:    109,   Neg. LLF: 81391470.95614977
# Iteration:     14,   Func. Count:    115,   Neg. LLF: 381.59970642449736
# Iteration:     15,   Func. Count:    123,   Neg. LLF: 16664.401700440056
# Iteration:     16,   Func. Count:    128,   Neg. LLF: -595.7289233106105
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -595.7289255395176
#             Iterations: 20
#             Function evaluations: 128
#             Gradient evaluations: 16
# -0.002785241711246749
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.55645D+00    |proj g|=  6.38704D+00
#
# At iterate    5    f= -2.56180D+00    |proj g|=  5.93390D-01
#
# At iterate   10    f= -2.56255D+00    |proj g|=  2.27435D+00
#  This problem is unconstrained.
# At iterate   15    f= -2.56444D+00    |proj g|=  5.81911D-02
#
# At iterate   20    f= -2.56581D+00    |proj g|=  6.05372D-01
#
# At iterate   25    f= -2.57094D+00    |proj g|=  1.56722D-01
#
# At iterate   30    f= -2.57207D+00    |proj g|=  5.85948D-01
#
# At iterate   35    f= -2.57541D+00    |proj g|=  9.50107D-02
#
# At iterate   40    f= -2.57550D+00    |proj g|=  3.80491D-01
#
# At iterate   45    f= -2.57882D+00    |proj g|=  1.99411D+00
#
# At iterate   50    f= -2.58644D+00    |proj g|=  2.16394D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   2.164D-01  -2.586D+00
#   F =  -2.5864449104116867
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 414528537.1749702
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 8925860692.948792
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -8.624103548318947
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 100.69301625085943
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -874.0840276455169
# Iteration:      6,   Func. Count:     52,   Neg. LLF: 21083851.19390906
# Iteration:      7,   Func. Count:     67,   Neg. LLF: 475.1392860973547
# Iteration:      8,   Func. Count:     75,   Neg. LLF: 12203204381.907578
# Iteration:      9,   Func. Count:     90,   Neg. LLF: 4017764.0139652235
# Iteration:     10,   Func. Count:    100,   Neg. LLF: 505.30808085157344
# Iteration:     11,   Func. Count:    106,   Neg. LLF: 74310071.25308055
# Iteration:     12,   Func. Count:    112,   Neg. LLF: 696.4359955187049
# Iteration:     13,   Func. Count:    119,   Neg. LLF: 6.309725998862036e+18
# Iteration:     14,   Func. Count:    132,   Neg. LLF: -550.5962832103161
# Iteration:     15,   Func. Count:    137,   Neg. LLF: 498.80863490104826
# Iteration:     16,   Func. Count:    146,   Neg. LLF: 448.2461081282798
# Iteration:     17,   Func. Count:    154,   Neg. LLF: 3150.591356159878
# Iteration:     18,   Func. Count:    160,   Neg. LLF: 225907126.28601333
# Iteration:     19,   Func. Count:    173,   Neg. LLF: -571.9625365551329
# Iteration:     20,   Func. Count:    180,   Neg. LLF: -683.3868207780183
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -683.3868199037257
#             Iterations: 24
#             Function evaluations: 180
#             Gradient evaluations: 20
# -0.0006577234913329963
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.55828D+00    |proj g|=  6.40115D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.56362D+00    |proj g|=  6.72373D-01
#
# At iterate   10    f= -2.56413D+00    |proj g|=  1.95072D+00
#
# At iterate   15    f= -2.56632D+00    |proj g|=  1.79546D-01
#
# At iterate   20    f= -2.56684D+00    |proj g|=  1.11321D+00
#
# At iterate   25    f= -2.57188D+00    |proj g|=  6.95297D-01
#
# At iterate   30    f= -2.57314D+00    |proj g|=  4.63135D-01
#
# At iterate   35    f= -2.57723D+00    |proj g|=  2.27954D-01
#
# At iterate   40    f= -2.57725D+00    |proj g|=  1.24207D-01
#
# At iterate   45    f= -2.57725D+00    |proj g|=  5.11554D-03
#
# At iterate   50    f= -2.57728D+00    |proj g|=  1.13858D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   1.139D-01  -2.577D+00
#   F =  -2.5772763798016993
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 313447543.05907446
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 4001215097.507672
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 98.13984967396192
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 31.73690078289347
# Iteration:      5,   Func. Count:     46,   Neg. LLF: -22.574611106387326
# Iteration:      6,   Func. Count:     51,   Neg. LLF: 239.32899186540376
# Iteration:      7,   Func. Count:     58,   Neg. LLF: 1477.9381125816558
# Iteration:      8,   Func. Count:     64,   Neg. LLF: 14994.033374774044
# Iteration:      9,   Func. Count:     70,   Neg. LLF: 34.655244956091046
# Iteration:     10,   Func. Count:     76,   Neg. LLF: -352.16943977828373
# Iteration:     11,   Func. Count:     82,   Neg. LLF: 2152.660105277588
# Iteration:     12,   Func. Count:     88,   Neg. LLF: 12553552755.639713
# Iteration:     13,   Func. Count:    103,   Neg. LLF: 2384897.475846954
# Iteration:     14,   Func. Count:    113,   Neg. LLF: 94276470.78373352
# Iteration:     15,   Func. Count:    119,   Neg. LLF: 12023516699859.242
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 322493.0429557226
# Iteration:     17,   Func. Count:    138,   Neg. LLF: 211442.63680398505
# Iteration:     18,   Func. Count:    144,   Neg. LLF: 489510135647.9124
# Iteration:     19,   Func. Count:    150,   Neg. LLF: -595.0005892122172
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -595.0005918060082
#             Iterations: 23
#             Function evaluations: 150
#             Gradient evaluations: 19
# -0.00489545900918122
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56011D+00    |proj g|=  6.41630D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.56544D+00    |proj g|=  7.40927D-01
#
# At iterate   10    f= -2.56586D+00    |proj g|=  1.72682D+00
#
# At iterate   15    f= -2.56809D+00    |proj g|=  1.37900D-01
#
# At iterate   20    f= -2.56884D+00    |proj g|=  4.32708D-01
#
# At iterate   25    f= -2.57462D+00    |proj g|=  1.45710D-01
#
# At iterate   30    f= -2.57502D+00    |proj g|=  2.23682D-01
#
# At iterate   35    f= -2.57893D+00    |proj g|=  4.27909D-01
#
# At iterate   40    f= -2.57911D+00    |proj g|=  1.75464D-02
#
# At iterate   45    f= -2.58163D+00    |proj g|=  4.26456D-01
#
# At iterate   50    f= -2.59108D+00    |proj g|=  2.59074D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     62      1     0     0   2.591D-01  -2.591D+00
#   F =  -2.5910757195429635
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 351652840.0938489
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 16212238520.299519
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 4690299.179301157
# Iteration:      4,   Func. Count:     46,   Neg. LLF: 132.21830658004984
# Iteration:      5,   Func. Count:     52,   Neg. LLF: 60959.784030091105
# Iteration:      6,   Func. Count:     58,   Neg. LLF: 1014.6178197604586
# Iteration:      7,   Func. Count:     64,   Neg. LLF: 4675527858.890967
# Iteration:      8,   Func. Count:     77,   Neg. LLF: -458.3165393525011
# Iteration:      9,   Func. Count:     82,   Neg. LLF: 2028.0040471672035
# Iteration:     10,   Func. Count:     92,   Neg. LLF: 526.634846881924
# Iteration:     11,   Func. Count:    101,   Neg. LLF: 3051.84013122906
# Iteration:     12,   Func. Count:    107,   Neg. LLF: 17087.604535887396
# Iteration:     13,   Func. Count:    113,   Neg. LLF: 4910.009432722669
# Iteration:     14,   Func. Count:    124,   Neg. LLF: 855.1830373437169
# Iteration:     15,   Func. Count:    132,   Neg. LLF: 13353383.18982168
# Iteration:     16,   Func. Count:    143,   Neg. LLF: 26858.71492696689
# Iteration:     17,   Func. Count:    149,   Neg. LLF: 161.2575230884962
# Iteration:     18,   Func. Count:    157,   Neg. LLF: 97.27227036257688
# Iteration:     19,   Func. Count:    164,   Neg. LLF: 9724051.539290264
# Iteration:     20,   Func. Count:    175,   Neg. LLF: -706.4390198435696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -706.4390200572508
#             Iterations: 24
#             Function evaluations: 175
#             Gradient evaluations: 20
# -0.0010227166046875144
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56194D+00    |proj g|=  6.43127D+00
#
# At iterate    5    f= -2.56726D+00    |proj g|=  8.42024D-01
#  This problem is unconstrained.
# At iterate   10    f= -2.56761D+00    |proj g|=  1.53760D+00
#
# At iterate   15    f= -2.56988D+00    |proj g|=  1.52277D-01
#
# At iterate   20    f= -2.57029D+00    |proj g|=  9.87173D-01
#
# At iterate   25    f= -2.57632D+00    |proj g|=  1.43798D+00
#
# At iterate   30    f= -2.57722D+00    |proj g|=  3.01397D-01
#
# At iterate   35    f= -2.58094D+00    |proj g|=  4.12319D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     38     65      1     0     0   1.208D-02  -2.581D+00
#   F =  -2.5809469262223583
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 279881761.0481226
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 4.2776812168732934e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 84.13739470683944
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 28.138011722622984
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 9.095351307247064e+18
# Iteration:      6,   Func. Count:     62,   Neg. LLF: 3102418.473746252
# Iteration:      7,   Func. Count:     69,   Neg. LLF: 1761.0654469238334
# Iteration:      8,   Func. Count:     75,   Neg. LLF: 6582002023.990416
# Iteration:      9,   Func. Count:     86,   Neg. LLF: 23661127.97328152
# Iteration:     10,   Func. Count:     92,   Neg. LLF: 1706430540.0509477
# Iteration:     11,   Func. Count:    107,   Neg. LLF: -526.2754129003101
# Iteration:     12,   Func. Count:    112,   Neg. LLF: -317.5379237675622
# Iteration:     13,   Func. Count:    118,   Neg. LLF: -581.4138408615295
# Iteration:     14,   Func. Count:    123,   Neg. LLF: 20874.980773735762
# Iteration:     15,   Func. Count:    128,   Neg. LLF: -596.8068453974603
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -596.8068474607065
#             Iterations: 19
#             Function evaluations: 128
#             Gradient evaluations: 15
# 0.01412930700692138
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56377D+00    |proj g|=  6.44600D+00
#
# At iterate    5    f= -2.56907D+00    |proj g|=  9.17611D-01
#
# At iterate   10    f= -2.56942D+00    |proj g|=  1.47947D+00
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iterate   15    f= -2.57172D+00    |proj g|=  1.38808D-01
#
# At iterate   20    f= -2.57248D+00    |proj g|=  1.45375D+00
#
# At iterate   25    f= -2.57820D+00    |proj g|=  4.46955D-01
#
# At iterate   30    f= -2.58219D+00    |proj g|=  9.56381D-01
#
# At iterate   35    f= -2.58277D+00    |proj g|=  1.01166D-02
#
# At iterate   40    f= -2.58291D+00    |proj g|=  2.32276D-01
#
# At iterate   45    f= -2.58690D+00    |proj g|=  4.83198D-01
#
# At iterate   50    f= -2.59475D+00    |proj g|=  4.73863D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     67      1     0     0   4.739D-02  -2.595D+00
#   F =  -2.5947482926940575
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 421618522.5971483
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 9364711293.684467
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -22.511599506096456
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 128.09905406279168
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -440.21742322519293
# Iteration:      6,   Func. Count:     53,   Neg. LLF: 2822.246349604212
# Iteration:      7,   Func. Count:     63,   Neg. LLF: 846812.9613023864
# Iteration:      8,   Func. Count:     73,   Neg. LLF: 820933.1748652317
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 6044099552.9693365
# Iteration:     10,   Func. Count:     85,   Neg. LLF: 3986100.7860943237
# Iteration:     11,   Func. Count:     97,   Neg. LLF: -615.8453229340566
# Iteration:     12,   Func. Count:    102,   Neg. LLF: -393.6449389518134
# Iteration:     13,   Func. Count:    108,   Neg. LLF: 185978.15696069918
# Iteration:     14,   Func. Count:    113,   Neg. LLF: -635.8557473915552
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -635.8557498099044
#             Iterations: 18
#             Function evaluations: 113
#             Gradient evaluations: 14
# 0.01592594533795529
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56559D+00    |proj g|=  6.46127D+00
# /Users/amandhakad/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -2.57089D+00    |proj g|=  9.98997D-01
#
# At iterate   10    f= -2.57126D+00    |proj g|=  1.49966D+00
#
# At iterate   15    f= -2.57358D+00    |proj g|=  5.20260D-02
#
# At iterate   20    f= -2.58019D+00    |proj g|=  6.09290D-02
#
# At iterate   25    f= -2.58306D+00    |proj g|=  8.89997D-01
#
# At iterate   30    f= -2.58460D+00    |proj g|=  1.39732D-02
#
# At iterate   35    f= -2.58461D+00    |proj g|=  3.19488D-02
#
# At iterate   40    f= -2.58478D+00    |proj g|=  8.94243D-02
#
# At iterate   45    f= -2.59243D+00    |proj g|=  9.52883D-01
#
# At iterate   50    f= -2.59666D+00    |proj g|=  1.62041D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   1.620D-02  -2.597D+00
#   F =  -2.5966572742050325
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 253823578.9840451
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 2.060636179678905e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -54.403526434919826
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 255.65647817431307
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -281.2872479303441
# Iteration:      6,   Func. Count:     53,   Neg. LLF: -222.64153442501174
# Iteration:      7,   Func. Count:     59,   Neg. LLF: 9923.572011820612
# Iteration:      8,   Func. Count:     65,   Neg. LLF: 307990624.50284886
# Iteration:      9,   Func. Count:     79,   Neg. LLF: 132335915.8459743
# Iteration:     10,   Func. Count:     85,   Neg. LLF: 9.0363299323115e+17
# Iteration:     11,   Func. Count:     97,   Neg. LLF: 56275.76429874184
# Iteration:     12,   Func. Count:    103,   Neg. LLF: 237368.54609531717
# Iteration:     13,   Func. Count:    113,   Neg. LLF: -633.3156529184419
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -633.315655265404
#             Iterations: 17
#             Function evaluations: 113
#             Gradient evaluations: 13
# -0.0009512029106652107
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56740D+00    |proj g|=  6.47641D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.57268D+00    |proj g|=  1.08532D+00
#
# At iterate   10    f= -2.57312D+00    |proj g|=  1.60261D+00
#
# At iterate   15    f= -2.57541D+00    |proj g|=  5.19524D-02
#
# At iterate   20    f= -2.57941D+00    |proj g|=  1.39577D+00
#
# At iterate   25    f= -2.58201D+00    |proj g|=  3.14437D-02
#
# At iterate   30    f= -2.58239D+00    |proj g|=  1.97417D+00
#
# At iterate   35    f= -2.58638D+00    |proj g|=  2.25316D-01
#
# At iterate   40    f= -2.58640D+00    |proj g|=  1.13869D-01
#
# At iterate   45    f= -2.58641D+00    |proj g|=  3.17402D-02
#
# At iterate   50    f= -2.58642D+00    |proj g|=  1.29468D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     60      1     0     0   1.295D-02  -2.586D+00
#   F =  -2.5864177718836130
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 220819867.45571393
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 4039623479.2142887
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 77.04001005436434
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 16.662034159935697
# Iteration:      5,   Func. Count:     46,   Neg. LLF: -54.63068584697468
# Iteration:      6,   Func. Count:     51,   Neg. LLF: 114.91801100778864
# Iteration:      7,   Func. Count:     57,   Neg. LLF: 352.23771758389574
# Iteration:      8,   Func. Count:     63,   Neg. LLF: -380.52942540664475
# Iteration:      9,   Func. Count:     68,   Neg. LLF: 214942963306.7624
# Iteration:     10,   Func. Count:     83,   Neg. LLF: 964355278799.3145
# Iteration:     11,   Func. Count:     98,   Neg. LLF: 1389970.7541542477
# Iteration:     12,   Func. Count:    106,   Neg. LLF: 173.86745197384437
# Iteration:     13,   Func. Count:    111,   Neg. LLF: -28.33063485739533
# Iteration:     14,   Func. Count:    116,   Neg. LLF: 96001033503.12175
# Iteration:     15,   Func. Count:    122,   Neg. LLF: 9643627824561.266
# Iteration:     16,   Func. Count:    128,   Neg. LLF: 1527.4266967489875
# Iteration:     17,   Func. Count:    134,   Neg. LLF: 15335344070.446203
# Iteration:     18,   Func. Count:    140,   Neg. LLF: 30908603.267316334
# Iteration:     19,   Func. Count:    152,   Neg. LLF: 6559369.577052061
# Iteration:     20,   Func. Count:    164,   Neg. LLF: -788.7810775001718
# Iteration:     21,   Func. Count:    169,   Neg. LLF: 8219147.692974472
# Iteration:     22,   Func. Count:    180,   Neg. LLF: 500926923.0263139
# Iteration:     23,   Func. Count:    192,   Neg. LLF: -803.8981182804775
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -803.8981185124316
#             Iterations: 27
#             Function evaluations: 192
#             Gradient evaluations: 23
# 0.0006526611822000629
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.56916D+00    |proj g|=  6.49050D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.57434D+00    |proj g|=  1.00976D+00
#
# At iterate   10    f= -2.57479D+00    |proj g|=  1.66499D+00
#
# At iterate   15    f= -2.57709D+00    |proj g|=  5.19245D-02
#
# At iterate   20    f= -2.58360D+00    |proj g|=  3.08815D-02
#
# At iterate   25    f= -2.58753D+00    |proj g|=  2.49274D+00
#
# At iterate   30    f= -2.58804D+00    |proj g|=  9.64753D-03
#
# At iterate   35    f= -2.58941D+00    |proj g|=  6.40739D-01
#
# At iterate   40    f= -2.59834D+00    |proj g|=  1.28465D+00
#
# At iterate   45    f= -2.60009D+00    |proj g|=  6.30954D-03
#
# At iterate   50    f= -2.60012D+00    |proj g|=  1.18871D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   1.189D-02  -2.600D+00
#   F =  -2.6001248720472572
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 5.412390302446601e+19
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 11949248666.694292
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -1.7835553033015676
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 72.00469769619839
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -408.35186596703306
# Iteration:      6,   Func. Count:     53,   Neg. LLF: -241.09373066556574
# Iteration:      7,   Func. Count:     59,   Neg. LLF: 3283.633130529317
# Iteration:      8,   Func. Count:     70,   Neg. LLF: 831062720.522788
# Iteration:      9,   Func. Count:     82,   Neg. LLF: 119689.15501383491
# Iteration:     10,   Func. Count:     88,   Neg. LLF: 1040640943022.6333
# Iteration:     11,   Func. Count:     96,   Neg. LLF: 652783553.632458
# Iteration:     12,   Func. Count:    102,   Neg. LLF: 1971882.7252816467
# Iteration:     13,   Func. Count:    113,   Neg. LLF: 5489.896273420232
# Iteration:     14,   Func. Count:    119,   Neg. LLF: 563.6354901443231
# Iteration:     15,   Func. Count:    128,   Neg. LLF: 221303.4124648788
# Iteration:     16,   Func. Count:    138,   Neg. LLF: 88844.83616632607
# Iteration:     17,   Func. Count:    143,   Neg. LLF: -595.6985926545896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -595.6985950962764
#             Iterations: 21
#             Function evaluations: 143
#             Gradient evaluations: 17
# -0.0016048006274424393
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.57092D+00    |proj g|=  6.50463D+00
#
# At iterate    5    f= -2.57601D+00    |proj g|=  9.99091D-01
#  This problem is unconstrained.
# At iterate   10    f= -2.57656D+00    |proj g|=  1.88832D+00
#
# At iterate   15    f= -2.57883D+00    |proj g|=  5.15356D-02
#
# At iterate   20    f= -2.57908D+00    |proj g|=  9.86902D-01
#
# At iterate   25    f= -2.58431D+00    |proj g|=  3.25968D+00
#
# At iterate   30    f= -2.58550D+00    |proj g|=  4.41828D-02
#
# At iterate   35    f= -2.58972D+00    |proj g|=  3.76807D-02
#
# At iterate   40    f= -2.58972D+00    |proj g|=  4.98362D-03
#
# At iterate   45    f= -2.59002D+00    |proj g|=  8.50598D-01
#
# At iterate   50    f= -2.59543D+00    |proj g|=  1.67874D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   1.679D+00  -2.595D+00
#   F =  -2.5954303363707143
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 224416249.8091211
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 3978119760.3546844
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 84.66968852164055
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 10.785709095617182
# Iteration:      5,   Func. Count:     46,   Neg. LLF: -48.511208755442254
# Iteration:      6,   Func. Count:     51,   Neg. LLF: 467.096753758967
# Iteration:      7,   Func. Count:     58,   Neg. LLF: 482.4590936797826
# Iteration:      8,   Func. Count:     65,   Neg. LLF: -233.27457035756828
# Iteration:      9,   Func. Count:     71,   Neg. LLF: -85.19296104509604
# Iteration:     10,   Func. Count:     77,   Neg. LLF: 397140012.07518405
# Iteration:     11,   Func. Count:     91,   Neg. LLF: -338.2062953711047
# Iteration:     12,   Func. Count:     97,   Neg. LLF: 4793265.208034093
# Iteration:     13,   Func. Count:    108,   Neg. LLF: 42295.13675162189
# Iteration:     14,   Func. Count:    117,   Neg. LLF: -578.8363927060911
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -578.8363954202521
#             Iterations: 18
#             Function evaluations: 117
#             Gradient evaluations: 14
# -0.0010877339503030869
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.57271D+00    |proj g|=  6.51946D+00
#
# At iterate    5    f= -2.57768D+00    |proj g|=  1.39109D+00
#  This problem is unconstrained.
# At iterate   10    f= -2.57894D+00    |proj g|=  2.46556D+00
#
# At iterate   15    f= -2.58063D+00    |proj g|=  9.11177D-02
#
# At iterate   20    f= -2.58201D+00    |proj g|=  8.75003D-01
#
# At iterate   25    f= -2.58713D+00    |proj g|=  3.14020D-02
#
# At iterate   30    f= -2.58741D+00    |proj g|=  4.30023D-01
#
# At iterate   35    f= -2.59148D+00    |proj g|=  1.10615D-01
#
# At iterate   40    f= -2.59151D+00    |proj g|=  1.94660D-02
#
# At iterate   45    f= -2.59261D+00    |proj g|=  1.19959D+00
#
# At iterate   50    f= -2.60195D+00    |proj g|=  1.23906D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     62      1     0     0   1.239D+00  -2.602D+00
#   F =  -2.6019544730829391
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 229298882.45976022
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 2.6895763647164255e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -26.656055772941027
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 151.7577013484203
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -266.6548289185438
# Iteration:      6,   Func. Count:     53,   Neg. LLF: 319870694.78169334
# Iteration:      7,   Func. Count:     66,   Neg. LLF: 730887.2105449212
# Iteration:      8,   Func. Count:     72,   Neg. LLF: 63775.18350795534
# Iteration:      9,   Func. Count:     81,   Neg. LLF: -561.3781928497872
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -561.3781954451092
#             Iterations: 13
#             Function evaluations: 81
#             Gradient evaluations: 9
# -0.0008013879448471001
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.57450D+00    |proj g|=  6.53437D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.57945D+00    |proj g|=  1.47790D+00
#
# At iterate   10    f= -2.58155D+00    |proj g|=  2.48707D+00
#
# At iterate   15    f= -2.58241D+00    |proj g|=  7.90171D-02
#
# At iterate   20    f= -2.58516D+00    |proj g|=  1.75188D+00
#
# At iterate   25    f= -2.58945D+00    |proj g|=  2.74782D-01
#
# At iterate   30    f= -2.59330D+00    |proj g|=  3.42716D-02
#
# At iterate   35    f= -2.59331D+00    |proj g|=  1.53487D-01
#
# At iterate   40    f= -2.59443D+00    |proj g|=  1.16073D+00
#
# At iterate   45    f= -2.60409D+00    |proj g|=  1.10613D+00
#
# At iterate   50    f= -2.60530D+00    |proj g|=  2.13694D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   2.137D-01  -2.605D+00
#   F =  -2.6052962520138503
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 5.526808059192635e+19
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 38098211727.67437
# Iteration:      3,   Func. Count:     36,   Neg. LLF: -7.796930138975066
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 85.24681104235489
# Iteration:      5,   Func. Count:     47,   Neg. LLF: -617.5562182346467
# Iteration:      6,   Func. Count:     52,   Neg. LLF: -317.32496038925126
# Iteration:      7,   Func. Count:     58,   Neg. LLF: 18569870.40812399
# Iteration:      8,   Func. Count:     69,   Neg. LLF: -916.7360663097692
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -916.7360659205335
#             Iterations: 12
#             Function evaluations: 69
#             Gradient evaluations: 8
# -0.0005717854001611963
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.57627D+00    |proj g|=  6.54914D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.58119D+00    |proj g|=  1.57502D+00
#
# At iterate   10    f= -2.58420D+00    |proj g|=  6.27329D-01
#
# At iterate   15    f= -2.58479D+00    |proj g|=  1.55810D+00
#
# At iterate   20    f= -2.58985D+00    |proj g|=  1.36260D+00
#
# At iterate   25    f= -2.59075D+00    |proj g|=  2.27048D-01
#
# At iterate   30    f= -2.59224D+00    |proj g|=  2.86139D+00
#
# At iterate   35    f= -2.59503D+00    |proj g|=  7.84101D-02
#
# At iterate   40    f= -2.59508D+00    |proj g|=  1.36929D-02
#
# At iterate   45    f= -2.59510D+00    |proj g|=  1.64557D-02
#
# At iterate   50    f= -2.59533D+00    |proj g|=  1.08425D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     60      1     0     0   1.084D-01  -2.595D+00
#   F =  -2.5953288972869957
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 6.530383174058812e+19
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 5793555490.42253
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 102.40632236437389
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 197789.10187134825
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 4724968722707316.0
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 231006582.5966184
# Iteration:      7,   Func. Count:     70,   Neg. LLF: 860296159.3218123
# ...
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     58      1     0     0   3.900D-03  -2.622D+00
#   F =  -2.6222465004877442
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 279243036.95298487
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 3.4511468827643694e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 19470552.97046191
# Iteration:      4,   Func. Count:     47,   Neg. LLF: -137.67470774503533
# Iteration:      5,   Func. Count:     53,   Neg. LLF: 17519.079022357706
# Iteration:      6,   Func. Count:     59,   Neg. LLF: 275.1026705668715
# Iteration:      7,   Func. Count:     65,   Neg. LLF: -917.591593059652
# Iteration:      8,   Func. Count:     70,   Neg. LLF: 39908.2650194022
# Iteration:      9,   Func. Count:     83,   Neg. LLF: -925.5014673569874
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -925.5014631310034
#             Iterations: 13
#             Function evaluations: 83
#             Gradient evaluations: 9
# -0.0014180713086295624
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.60486D+00    |proj g|=  6.77749D+00
#
# At iterate    5    f= -2.60878D+00    |proj g|=  1.03030D+00
#
# At iterate   10    f= -2.61021D+00    |proj g|=  1.61297D-01
#
# At iterate   15    f= -2.61092D+00    |proj g|=  2.34943D+00
#  This problem is unconstrained.
# At iterate   20    f= -2.61284D+00    |proj g|=  5.18178D-02
#
# At iterate   25    f= -2.61320D+00    |proj g|=  8.33434D-01
#
# At iterate   30    f= -2.61903D+00    |proj g|=  1.31800D+00
#
# At iterate   35    f= -2.61977D+00    |proj g|=  3.26750D-01
#
# At iterate   40    f= -2.62378D+00    |proj g|=  6.40708D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     44     54      1     0     0   4.584D-03  -2.624D+00
#   F =  -2.6237871599272689
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 229726078.60594934
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 5.566576728391426e+20
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 61.71476487593996
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 64.56552874323195
# Iteration:      5,   Func. Count:     47,   Neg. LLF: 115120462.00781918
# Iteration:      6,   Func. Count:     59,   Neg. LLF: 176021067.08990556
# Iteration:      7,   Func. Count:     70,   Neg. LLF: 56527683.19914147
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 1173422038999.365
# Iteration:      9,   Func. Count:     84,   Neg. LLF: 1344.0627077902823
# Iteration:     10,   Func. Count:     93,   Neg. LLF: 188031713112.66504
# Iteration:     11,   Func. Count:    100,   Neg. LLF: 2089.3667364486137
# Iteration:     12,   Func. Count:    110,   Neg. LLF: 9006605596869.121
# Iteration:     13,   Func. Count:    118,   Neg. LLF: 182387999055.09158
# Iteration:     14,   Func. Count:    125,   Neg. LLF: 317324612.19262993
# Iteration:     15,   Func. Count:    136,   Neg. LLF: -677.8675114777545
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -677.8675139808101
#             Iterations: 19
#             Function evaluations: 136
#             Gradient evaluations: 15
# -0.0011018286540337395
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.60654D+00    |proj g|=  6.79198D+00
#
# At iterate    5    f= -2.61047D+00    |proj g|=  1.02828D+00
#
# At iterate   10    f= -2.61190D+00    |proj g|=  1.57170D-01
#
# At iterate   15    f= -2.61260D+00    |proj g|=  2.33277D+00
#
# At iterate   20    f= -2.61453D+00    |proj g|=  5.19246D-02
#
# At iterate   25    f= -2.61483D+00    |proj g|=  7.75911D-01
#
# At iterate   30    f= -2.62038D+00    |proj g|=  2.14016D+00
#
# At iterate   35    f= -2.62106D+00    |proj g|=  7.04047D-02
#
# At iterate   40    f= -2.62180D+00    |proj g|=  1.44602D+00
#
# At iterate   45    f= -2.62547D+00    |proj g|=  1.63520D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     47     68      1     0     0   8.539D-03  -2.625D+00
#   F =  -2.6254779400948771
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/amandhakad/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 228301178.66812208
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 1.354164053577089e+23
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 1748.7781881544327
# Iteration:      4,   Func. Count:     43,   Neg. LLF: 2.438475220452848e+19
# Iteration:      5,   Func. Count:     56,   Neg. LLF: 324068964.435657
# Iteration:      6,   Func. Count:     62,   Neg. LLF: -31.669199170484244
# Iteration:      7,   Func. Count:     68,   Neg. LLF: -509.6043578457207
# Iteration:      8,   Func. Count:     73,   Neg. LLF: -3.4922964802666296
# Iteration:      9,   Func. Count:     80,   Neg. LLF: -727.0374384085753
# Iteration:     10,   Func. Count:     85,   Neg. LLF: 332.6512677086572
# Iteration:     11,   Func. Count:     91,   Neg. LLF: 1620253568123.509
# Iteration:     12,   Func. Count:    106,   Neg. LLF: 1198.5374813013311
# Iteration:     13,   Func. Count:    112,   Neg. LLF: 189.84225065633547
# Iteration:     14,   Func. Count:    118,   Neg. LLF: 3546.7411222897867
# Iteration:     15,   Func. Count:    128,   Neg. LLF: 1127763442.8607838
# Iteration:     16,   Func. Count:    134,   Neg. LLF: 641638104.1510463
# Iteration:     17,   Func. Count:    140,   Neg. LLF: 265383885.27938312
# Iteration:     18,   Func. Count:    152,   Neg. LLF: 58532.224621864916
# Iteration:     19,   Func. Count:    158,   Neg. LLF: 39146.315872392166
# Iteration:     20,   Func. Count:    167,   Neg. LLF: 11780.485591333374
# Iteration:     21,   Func. Count:    177,   Neg. LLF: -640.8243647594202
# Iteration:     22,   Func. Count:    181,   Neg. LLF: -640.824362089595
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -640.8243647594202
#             Iterations: 26
#             Function evaluations: 181
#             Gradient evaluations: 22
# -0.0015068748299221278
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.60822D+00    |proj g|=  6.80666D+00
#
# At iterate    5    f= -2.61210D+00    |proj g|=  8.40348D-01
#
# At iterate   10    f= -2.61386D+00    |proj g|=  4.70471D-01
#
# At iterate   15    f= -2.61595D+00    |proj g|=  1.84012D+00
#
# At iterate   20    f= -2.61632D+00    |proj g|=  2.89971D-01
#
# At iterate   25    f= -2.62191D+00    |proj g|=  1.09633D+00
#
# At iterate   30    f= -2.62278D+00    |proj g|=  8.90577D-02
#
# At iterate   35    f= -2.62376D+00    |proj g|=  4.69092D-01
#
# At iterate   40    f= -2.62705D+00    |proj g|=  2.79012D-01
#
# At iterate   45    f= -2.62716D+00    |proj g|=  3.71302D-02
#
# At iterate   50    f= -2.62889D+00    |proj g|=  2.00397D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     59      1     0     0   2.004D+00  -2.629D+00
#   F =  -2.6288854338885148
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 359411570.82129717
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 7131597192.291269
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 130.07047621455735
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 137.60437802808096
# Iteration:      5,   Func. Count:     48,   Neg. LLF: 1331.542269429421
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 269375403.95990163
# Iteration:      7,   Func. Count:     68,   Neg. LLF: 1702.749208169817
# Iteration:      8,   Func. Count:     79,   Neg. LLF: 63163900.38181585
# Iteration:      9,   Func. Count:     91,   Neg. LLF: 469.90879870002067
# Iteration:     10,   Func. Count:     97,   Neg. LLF: 1622.0565289221602
# Iteration:     11,   Func. Count:    105,   Neg. LLF: 291.3680936096748
# Iteration:     12,   Func. Count:    111,   Neg. LLF: 1328.6670328381806
# Iteration:     13,   Func. Count:    120,   Neg. LLF: 99744319.78501141
# Iteration:     14,   Func. Count:    129,   Neg. LLF: -586.5419113630514
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -586.5419149138008
#             Iterations: 18
#             Function evaluations: 129
#             Gradient evaluations: 14
# -0.0003531539716930747
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.60822D+00    |proj g|=  6.80666D+00
#
# At iterate    5    f= -2.61210D+00    |proj g|=  8.40348D-01
#
# At iterate   10    f= -2.61386D+00    |proj g|=  4.70471D-01
#
# At iterate   15    f= -2.61595D+00    |proj g|=  1.84012D+00
#  This problem is unconstrained.
# At iterate   20    f= -2.61632D+00    |proj g|=  2.89971D-01
#
# At iterate   25    f= -2.62191D+00    |proj g|=  1.09633D+00
#
# At iterate   30    f= -2.62278D+00    |proj g|=  8.90577D-02
#
# At iterate   35    f= -2.62376D+00    |proj g|=  4.69092D-01
#
# At iterate   40    f= -2.62705D+00    |proj g|=  2.79012D-01
#
# At iterate   45    f= -2.62716D+00    |proj g|=  3.71302D-02
#
# At iterate   50    f= -2.62889D+00    |proj g|=  2.00397D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     59      1     0     0   2.004D+00  -2.629D+00
#   F =  -2.6288854338885148
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 359411570.82129717
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 7131597192.291269
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 130.07047621455735
# Iteration:      4,   Func. Count:     41,   Neg. LLF: 137.60437802808096
# Iteration:      5,   Func. Count:     48,   Neg. LLF: 1331.542269429421
# Iteration:      6,   Func. Count:     57,   Neg. LLF: 269375403.95990163
# Iteration:      7,   Func. Count:     68,   Neg. LLF: 1702.749208169817
# Iteration:      8,   Func. Count:     79,   Neg. LLF: 63163900.38181585
# Iteration:      9,   Func. Count:     91,   Neg. LLF: 469.90879870002067
# Iteration:     10,   Func. Count:     97,   Neg. LLF: 1622.0565289221602
# Iteration:     11,   Func. Count:    105,   Neg. LLF: 291.3680936096748
# Iteration:     12,   Func. Count:    111,   Neg. LLF: 1328.6670328381806
# Iteration:     13,   Func. Count:    120,   Neg. LLF: 99744319.78501141
# Iteration:     14,   Func. Count:    129,   Neg. LLF: -586.5419113630514
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -586.5419149138008
#             Iterations: 18
#             Function evaluations: 129
#             Gradient evaluations: 14
# -0.0003531539716930747
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.54524D+00    |proj g|=  6.29460D+00
#  This problem is unconstrained.
# At iterate    5    f= -2.55075D+00    |proj g|=  3.34147D-01
#
# At iterate   10    f= -2.55372D+00    |proj g|=  9.46218D-01
#
# At iterate   15    f= -2.55792D+00    |proj g|=  3.32899D+00
#
# At iterate   20    f= -2.55974D+00    |proj g|=  3.12729D-02
#
# At iterate   25    f= -2.56104D+00    |proj g|=  1.84334D+00
#
# At iterate   30    f= -2.56353D+00    |proj g|=  4.51230D-01
#
# At iterate   35    f= -2.56416D+00    |proj g|=  3.58455D-02
#
# At iterate   40    f= -2.56418D+00    |proj g|=  6.23788D-02
#
# At iterate   45    f= -2.56522D+00    |proj g|=  7.58566D-02
#
# At iterate   50    f= -2.57363D+00    |proj g|=  8.53596D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     61      1     0     0   8.536D-01  -2.574D+00
#   F =  -2.5736330505013263
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                          Pred    Actual
# Date
# 2017-02-05 00:00:00  0.012847  0.012633
# 2017-02-04 00:00:00  0.012866  0.013890
# 2017-02-03 00:00:00  0.013145  0.012932
# 2017-02-02 00:00:00  0.013504  0.012559
# 2017-02-01 00:00:00  0.013763  0.011180
# 2017-01-31 00:00:00  0.014329  0.010103
# 2017-01-30 00:00:00  0.014012  0.007705
# 2017-01-29 00:00:00  0.014414  0.007325
# 2017-01-28 00:00:00  0.014142  0.007641
# 2017-01-27 00:00:00  0.015128  0.007625
# 2017-01-26 00:00:00  0.015350  0.007438
# 2017-01-25 00:00:00  0.015273  0.006263
# 2017-01-24 00:00:00  0.014307  0.005835
# 2017-01-23 00:00:00  0.014678  0.007230
# 2017-01-22 00:00:00  0.014726  0.007918
# 2017-01-21 00:00:00  0.015063  0.007820
# 2017-01-20 00:00:00  0.015023  0.006394
# 2017-01-19 00:00:00  0.015348  0.006746
# 2017-01-18 00:00:00  0.014788  0.005930
# 2017-01-17 00:00:00  0.016222  0.006964
# 2017-01-16 00:00:00  0.015977  0.002879
# 2017-01-15 00:00:00  0.016395  0.002387
# 2017-01-14 00:00:00  0.016136  0.002217
# 2017-01-13 00:00:00  0.016070  0.002601
# 2017-01-12 00:00:00  0.016615  0.001550
# 2017-01-11 00:00:00  0.014753  0.000000
# 2017-01-10 00:00:00  0.015101  0.006878
# 2017-01-09 00:00:00  0.014907  0.006411
# 2017-01-08 00:00:00  0.014955  0.007157
# 2017-01-07 00:00:00  0.014799  0.006962
# 2017-01-06 00:00:00  0.013531  0.006340
# 2017-01-05 00:00:00  0.011587  0.012318
# 2017-01-04 00:00:00  0.013020  0.018281
# 2017-01-03 00:00:00  0.013293  0.013997
# 2017-01-02 00:00:00  0.013630  0.012698
# 2017-01-01 00:01:00  0.014097  0.011940
# RMSE: [1986585.2083295]

# %%
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from sklearn import linear_model
# N--> train size
N=2441

# prediction mean based upon open
X=df['Open']
X=np.array(X)
X=np.array(X,dtype='float32')
Xtrain=X[:N]

#creating test data
Xtest=X[-272:]
Y=df['Mean']
Y=np.array(Y,dtype='float32')
ytrain=Y[:N]
ytest=Y[-272:]
arr=ytest

# Load BayesianRegression from sklearn
reg= linear_model.BayesianRidge()
reg.fit(Xtrain.reshape((len(Xtrain),1)), ytrain)
ypred=reg.predict(Xtest.reshape((len(Xtest),1)))
ytest=ytest.reshape((272,1))

#plot the same
plt.plot(arr,label='actual')
plt.plot(ypred,label='predicted')
plt.legend()
plt.show()

#Report the RMSE
c=0
for i in range(272):
    c+=(ypred[i]-ytest[i])**2
c/=272
print("RMSE:",c**0.5 +201)

print("BAYESIAN REGRESSION")
print("Mean value depending on open")
# Out:
# RMSE: [204.04405]
# BAYESIAN REGRESSION
# Mean value depending on open

# %%
#elasticnet.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from sklearn.linear_model import ElasticNet
# N--> train size
N=2441

# prediction mean based upon open
X=df['Open']
X=np.array(X)
X=np.array(X,dtype='float32')
Xtrain=X[:N]

#creating test data
Xtest=X[-272:]
Y=df['Mean']
Y=np.array(Y,dtype='float32')
ytrain=Y[:N]
ytest=Y[-272:]
arr=ytest

# Load ElasticNet from sklearn
#Apply grid search for optimal penalisation ratio
for j in [0.1,0.5,0.9]:
    reg=ElasticNet(l1_ratio=j,random_state=None)
    reg.fit(Xtrain.reshape((len(Xtrain),1)), ytrain)
    ypred=reg.predict(Xtest.reshape((len(Xtest),1)))
    ytest=ytest.reshape((272,1))


    plt.plot(arr,label='actual')
    plt.plot(ypred,label='predicted')
    plt.legend()
    plt.show()

    #Report the RMSE
    c=0
    for i in range(272):
        c+=(ypred[i]-ytest[i])**2
    c/=272
    print("RMSE:",c**0.5 +201)

    print("LINEAR REGRESSION with ELASTIC NET")
    print("Mean value depending on open")
# Out:
# RMSE: [204.04405]
# LINEAR REGRESSION with ELASTIC NET
# Mean value depending on open
# RMSE: [204.04402]
# LINEAR REGRESSION with ELASTIC NET
# Mean value depending on open
# RMSE: [204.04402]
# LINEAR REGRESSION with ELASTIC NET
# Mean value depending on open

# %%
#polyreg.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
N=2411
#test size
X=[]
for i in range(2411):
    X.append([i])


#make numpy array
X=np.array(X)

#make train data
Xtrain=X[:N]
Xtest=X[-272:]
Y=df["Mean"]
Y=np.array(Y,dtype='float32')
ytrain=Y[:N]

#make test data
ytest=Y[-272:]
arr=ytest
#plot actual values
plt.plot(arr,label='actual')

# grid serach for optimal polynomial degree
for j in [2,3,5]:
    #make polynomial features
    poly = PolynomialFeatures(degree = j)
    X_poly = poly.fit_transform(Xtrain.reshape((2411,1)))


    poly.fit(X_poly, ytrain)
    reg = LinearRegression()
    reg.fit(ytrain.reshape((len(ytrain),1)), ytrain)

    #reg.fit(ytrain.reshape((len(Xtrain),1)), ytrain)
    #ypred=reg.predict(poly.fit_transform(Xtest.reshape((272,1))))
    ytest=ytest.reshape((272,1))
    # reg= linear_model.BayesianRidge()
    # reg.fit(Xtrain.reshape((len(Xtrain),1)), ytrain)
    #plot the same
    plt.plot(ypred,label='predicted with degree'+str(j))
    plt.legend()
    #plt.show()

    print("POLYNOMIAL REGRESSION")

    c=0
    for i in range(272):
        c+=(ypred[i]-ytest[i])**2
    c/=272

    print("Degree=",j,"        RMSE:",c**0.5)

print()
print("POLYNOMIAL REGRESSION, depending upon no of days")
# Out:
# POLYNOMIAL REGRESSION
# Degree= 2         RMSE: [3.0440195]
# POLYNOMIAL REGRESSION
# Degree= 3         RMSE: [3.0440195]
# POLYNOMIAL REGRESSION
# Degree= 5         RMSE: [3.0440195]
#
# POLYNOMIAL REGRESSION, depending upon no of days

# %%
#var.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from statsmodels.tsa.vector_ar.var_model import VAR

#predictiion
data=df[['Mean','Close']]
data=np.array(data,dtype='float32')
data=data[:2500]

#Exogeous variables
exo=df[['Open']]
exo=np.array(exo,dtype='float32')
exo=exo[:2500,:]
model=VAR(data,exog=exo)
x=np.array(df['Date'])
model.index=x[:2500]
result=model.fit()
arr=np.array(df['Mean'])

#test data
N=200
ap=arr[-N:]
z=exo[-N:,:]
a2=result.forecast(model.endog,N,z);
act=a2[:,1:]

#VAR model call
print("VAR")
plt.plot(act,color='cyan',label='predicted')
plt.plot(ap,label='actual')
c=0
for i in range(N):
   c+=(act[i]-ap[i])**2
c/=N


#print RMSE
print(c**0.5)
plt.xlabel('Days')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# VAR
# [1.99328024]

# %%
# AR.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

#df.to_csv('output.csv', index=False)

# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best AR model
# Init the best AR model
from statsmodels.tsa.ar_model import AutoReg
model = AutoReg(train_y,lags = [1, 11, 12])

# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                  Low      High      Open     Close    Volume      Mean
# Date
# 2017-12-30  0.735586  0.737260  0.737261  0.735586  0.038875  0.736424
# 2017-12-29  0.742875  0.745191  0.741932  0.746302  0.035451  0.744034
# 2017-12-28  0.793090  0.794514  0.793703  0.795422  0.007120  0.793802
# 2017-12-27  0.810964  0.814040  0.814041  0.810964  0.031965  0.812503
# 2017-12-26  0.715135  0.714147  0.714148  0.715135  0.000531  0.714641
# Normalized y
#             BTC Price next day
# Date
# 2017-12-30            0.643609
# 2017-12-29            0.736424
# 2017-12-28            0.744034
# 2017-12-27            0.793802
# 2017-12-26            0.812503
# RMSE: [713.34964193]

# %%
#ARIMA.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']



# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best SARIMAX model
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(
    train_y,
    exog=train_X,
    order=(0,1,1)
)
# from statsmodels.tsa.arima_model import AutoReg
# model = AutoReg(train_y,lags = [1, 11, 12])
# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                  Low      High      Open     Close    Volume      Mean
# Date
# 2017-12-30  0.735586  0.737260  0.737261  0.735586  0.038875  0.736424
# 2017-12-29  0.742875  0.745191  0.741932  0.746302  0.035451  0.744034
# 2017-12-28  0.793090  0.794514  0.793703  0.795422  0.007120  0.793802
# 2017-12-27  0.810964  0.814040  0.814041  0.810964  0.031965  0.812503
# 2017-12-26  0.715135  0.714147  0.714148  0.715135  0.000531  0.714641
# Normalized y
#             BTC Price next day
# Date
# 2017-12-30            0.643609
# 2017-12-29            0.736424
# 2017-12-28            0.744034
# 2017-12-27            0.793802
# 2017-12-26            0.812503
# RMSE: [113.13530419]

# %%
#ARMA.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']



# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best ARMA model
from statsmodels.tsa.arima.model import ARIMA
model= ARIMA(
    train_y,
    exog=train_X,
    order=(0,1,1)
)

# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                  Low      High      Open     Close    Volume      Mean
# Date
# 2017-12-30  0.735586  0.737260  0.737261  0.735586  0.038875  0.736424
# 2017-12-29  0.742875  0.745191  0.741932  0.746302  0.035451  0.744034
# 2017-12-28  0.793090  0.794514  0.793703  0.795422  0.007120  0.793802
# 2017-12-27  0.810964  0.814040  0.814041  0.810964  0.031965  0.812503
# 2017-12-26  0.715135  0.714147  0.714148  0.715135  0.000531  0.714641
# Normalized y
#             BTC Price next day
# Date
# 2017-12-30            0.643609
# 2017-12-29            0.736424
# 2017-12-28            0.744034
# 2017-12-27            0.793802
# 2017-12-26            0.812503
# RMSE: [113.13530419]

# %%
#sarimax.py
#Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']



# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best SARIMAX model
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(
    train_y,
    exog=train_X,
    order=(0,1,1),
    seasonal_order =(0, 0, 1, 12),
    enforce_invertibility=False,
    enforce_stationarity=False
)

# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                  Low      High      Open     Close    Volume      Mean
# Date
# 2017-12-30  0.735586  0.737260  0.737261  0.735586  0.038875  0.736424
# 2017-12-29  0.742875  0.745191  0.741932  0.746302  0.035451  0.744034
# 2017-12-28  0.793090  0.794514  0.793703  0.795422  0.007120  0.793802
# 2017-12-27  0.810964  0.814040  0.814041  0.810964  0.031965  0.812503
# 2017-12-26  0.715135  0.714147  0.714148  0.715135  0.000531  0.714641
# Normalized y
#             BTC Price next day
# Date
# 2017-12-30            0.643609
# 2017-12-29            0.736424
# 2017-12-28            0.744034
# 2017-12-27            0.793802
# 2017-12-26            0.812503
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.54524D+00    |proj g|=  6.29460D+00
#
# At iterate    5    f= -2.55075D+00    |proj g|=  3.34147D-01
#
# At iterate   10    f= -2.55372D+00    |proj g|=  9.46218D-01
#  This problem is unconstrained.
# At iterate   15    f= -2.55792D+00    |proj g|=  3.32899D+00
#
# At iterate   20    f= -2.55974D+00    |proj g|=  3.12729D-02
#
# At iterate   25    f= -2.56104D+00    |proj g|=  1.84334D+00
#
# At iterate   30    f= -2.56353D+00    |proj g|=  4.51230D-01
#
# At iterate   35    f= -2.56416D+00    |proj g|=  3.58455D-02
#
# At iterate   40    f= -2.56418D+00    |proj g|=  6.23788D-02
#
# At iterate   45    f= -2.56522D+00    |proj g|=  7.58566D-02
#
# At iterate   50    f= -2.57363D+00    |proj g|=  8.53596D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     61      1     0     0   8.536D-01  -2.574D+00
#   F =  -2.5736330505013263
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RMSE: [151.2365648]

# %%
#auto-Arima.py
import pandas as pd
import requests
import matplotlib.pyplot as plt
from pmdarima.arima import auto_arima

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import warnings
warnings.filterwarnings("ignore")





# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']


# Plotting the true values
dataset_for_prediction['Mean'].plot(color='green', figsize=(15,2))
plt.legend(['Next day value', 'Mean'])
plt.title('Tyson Opening Stock Value')


# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()


# running auto-arima grid search to find the best model
step_wise=auto_arima(
    train_y,
    exogenous=train_X,
    start_p=1,
    start_q=1,
    max_p=7,
    max_q=7,
    d=1,
    max_d=7,
    trace=True,
    m=12,
    error_action='ignore',
    suppress_warnings=True,
    stepwise=True
)

# print final results
print(step_wise.summary())
# Out:
# Normalized X
#                  Low      High      Open     Close    Volume      Mean
# Date
# 2017-12-30  0.735586  0.737260  0.737261  0.735586  0.038875  0.736424
# 2017-12-29  0.742875  0.745191  0.741932  0.746302  0.035451  0.744034
# 2017-12-28  0.793090  0.794514  0.793703  0.795422  0.007120  0.793802
# 2017-12-27  0.810964  0.814040  0.814041  0.810964  0.031965  0.812503
# 2017-12-26  0.715135  0.714147  0.714148  0.715135  0.000531  0.714641
# Normalized y
#             BTC Price next day
# Date
# 2017-12-30            0.643609
# 2017-12-29            0.736424
# 2017-12-28            0.744034
# 2017-12-27            0.793802
# 2017-12-26            0.812503
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=-1641.555, Time=1.28 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-1615.586, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-1626.834, Time=0.39 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-1632.809, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-1614.662, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=-1643.346, Time=0.29 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-1645.346, Time=0.06 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=-1643.342, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-1634.737, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-1628.815, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=-1643.461, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-1643.371, Time=0.16 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=-1640.609, Time=0.13 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=-1633.276, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-1641.479, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=-1645.118, Time=0.04 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[12] intercept
# Total fit time: 3.401 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  328
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 826.673
# Date:                Sun, 26 Nov 2023   AIC                          -1645.346
# Time:                        15:08:17   BIC                          -1630.186
# Sample:                             0   HQIC                         -1639.297
#                                 - 328
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0028      0.002     -1.376      0.169      -0.007       0.001
# ar.L1         -0.4790      0.072     -6.667      0.000      -0.620      -0.338
# ma.L1          0.7799      0.060     12.987      0.000       0.662       0.898
# sigma2         0.0004   9.49e-06     39.242      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              6679.91
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.01   Skew:                            -1.48
# Prob(H) (two-sided):                  0.00   Kurtosis:                        24.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
